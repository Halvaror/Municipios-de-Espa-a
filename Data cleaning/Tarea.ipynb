# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("DatosImpuestos_Tarea.xlsx")

# %%
df
# Out:
#       Distrito          CCAA  ActEconom  ActEconom_Cuali  Basura  Vehiculo  \
# 0           10   Extremadura     20.213                0  60.444    35.555
# 1           10   Extremadura     25.275                0  54.779    44.118
# 2           10   Extremadura     27.241                0  44.203    53.140
# 3           10   Extremadura     30.114                1  50.813    45.325
# 4           10   Extremadura     30.185                1  44.562    49.867
# ...        ...           ...        ...              ...     ...       ...
# 8114         9  CastillaLeón     21.951                0  50.000    43.750
# 8115         9  CastillaLeón     18.182                0  18.889    76.667
# 8116         9  CastillaLeón     15.152                0  25.000    71.429
# 8117         9  CastillaLeón     25.118                0  37.975    60.126
# 8118         9  CastillaLeón     21.818                0   9.302    83.721
#
# ...

# %%
df = df.sort_values(by="Distrito")

# %%
for i in df:
    print(df[i].value_counts())
# Out:
# 9     371
# 37    362
# 8     311
# 50    293
# 19    288
# 31    272
# 46    266
# 5     248
# 49    248
# 16    238
# 44    236
# 25    231
# 47    225
# 10    222
# 17    221
# 24    211
# 40    209
# 45    204
# 22    202
# 34    191
# 43    184
# 42    183
# 28    179
# 26    174
# 18    170
# 6     165
# 3     141
# 12    135
# 48    112
# 41    105
# 39    102
# 4     102
# 13    102
# 29    101
# 23     97
# 15     93
# 32     92
# 20     88
# 2      87
# 21     79
# 33     78
# 14     75
# 7      67
# 27     67
# 36     62
# 38     54
# 1      51
# 30     45
# 11     44
# 35     34
# 51      1
# 52      1
# Name: Distrito, dtype: int64
# CastillaLeón      2248
# Cataluña           947
# CastillaMancha     919
# Andalucía          773
# Aragón             731
# ComValenciana      542
# Extremadura        387
# Galicia            314
# Navarra            272
# PaísVasco          251
# Madrid             179
# Rioja              174
# Cantabria          102
# ...
